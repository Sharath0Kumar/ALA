# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharath0Kumar/ALA/blob/main/ALA_LAB1_Q7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from vec import Vec
import timeit

# %%
from vec import Vec
import time
import timeit

sizes= [2000, 4000, 8000, 16000, 32000, 64000]

# for size in sizes:
#     v1 = Vec.uniform(size)
#     v2 = Vec.uniform(size)

    # start = time.perf_counter()
    # result = v1 + v2
    # end = time.perf_counter()
    # print("Time : ", end -start ,"seconds")

    # time_taken = timeit.timeit(lambda: v1 + v2, number=10)
    # average_time = time_taken / 10
    # print(f"Size: {size}, Average Time: {average_time:.8f} seconds")


#Better way

def measure_time(operation , number = 10):
    total_time = timeit.timeit(operation, number=number)
    return total_time / number

for size in sizes:
    v1 = Vec.uniform(size)
    v2 = Vec.uniform(size)

    addition_time = measure_time(lambda: v1 + v2)
    subtraction_time = measure_time(lambda: v1 - v2)
    multiplication_time = measure_time(lambda: 2 * v1)
    inplace_multiplication_time = measure_time(lambda: v1.__imul__(2))
    inplace_addition_time = measure_time(lambda: v1.__iadd__(v2))
    negation_time = measure_time(lambda: -v1)
    norm_time = measure_time(lambda: v1.norm())

    print(f"-" *10 + f"Size : {size}" + "-"*10)

    print(f"Size: {size}, Addition Time: {addition_time:.8f} seconds")
    print(f"Size: {size}, Subtraction Time: {subtraction_time:.8f} seconds")
    print(f"Size: {size}, Multiplication Time: {multiplication_time:.8f} seconds")
    print(f"Size: {size}, In-place Multiplication Time: {inplace_multiplication_time:.8f} seconds")
    print(f"Size: {size}, In-place Addition Time: {inplace_addition_time:.8f} seconds")
    print(f"Size: {size}, Negation Time: {negation_time:.8f} seconds")
    print(f"Size: {size}, Norm Time: {norm_time:.8f} seconds")
# Out:
# ----------Size : 2000----------
# Size: 2000, Addition Time: 0.00162178 seconds
# Size: 2000, Subtraction Time: 0.00141943 seconds
# Size: 2000, Multiplication Time: 0.00161377 seconds
# Size: 2000, In-place Multiplication Time: 0.00127856 seconds
# Size: 2000, In-place Addition Time: 0.00124087 seconds
# Size: 2000, Negation Time: 0.00025228 seconds
# Size: 2000, Norm Time: 0.00018621 seconds
# ----------Size : 4000----------
# Size: 4000, Addition Time: 0.00283034 seconds
# Size: 4000, Subtraction Time: 0.00273750 seconds
# Size: 4000, Multiplication Time: 0.00268943 seconds
# Size: 4000, In-place Multiplication Time: 0.00251680 seconds
# Size: 4000, In-place Addition Time: 0.00268675 seconds
# Size: 4000, Negation Time: 0.00060073 seconds
# Size: 4000, Norm Time: 0.00042641 seconds
# ----------Size : 8000----------
# Size: 8000, Addition Time: 0.00585312 seconds
# Size: 8000, Subtraction Time: 0.00603722 seconds
# Size: 8000, Multiplication Time: 0.00546996 seconds
# Size: 8000, In-place Multiplication Time: 0.00509826 seconds
# Size: 8000, In-place Addition Time: 0.00507999 seconds
# Size: 8000, Negation Time: 0.00101695 seconds
# Size: 8000, Norm Time: 0.00070933 seconds
# ----------Size : 16000----------
# Size: 16000, Addition Time: 0.01144159 seconds
# Size: 16000, Subtraction Time: 0.01316854 seconds
# Size: 16000, Multiplication Time: 0.01145696 seconds
# Size: 16000, In-place Multiplication Time: 0.01025115 seconds
# Size: 16000, In-place Addition Time: 0.01016771 seconds
# Size: 16000, Negation Time: 0.00206467 seconds
# Size: 16000, Norm Time: 0.00141194 seconds
# ----------Size : 32000----------
# Size: 32000, Addition Time: 0.02332308 seconds
# Size: 32000, Subtraction Time: 0.02316080 seconds
# Size: 32000, Multiplication Time: 0.02396130 seconds
# Size: 32000, In-place Multiplication Time: 0.02038287 seconds
# Size: 32000, In-place Addition Time: 0.02094238 seconds
# Size: 32000, Negation Time: 0.00403823 seconds
# Size: 32000, Norm Time: 0.00284202 seconds
# ----------Size : 64000----------
# Size: 64000, Addition Time: 0.04520319 seconds
# Size: 64000, Subtraction Time: 0.04680198 seconds
# Size: 64000, Multiplication Time: 0.04514260 seconds
# Size: 64000, In-place Multiplication Time: 0.04215325 seconds
# Size: 64000, In-place Addition Time: 0.04642747 seconds
# Size: 64000, Negation Time: 0.00813454 seconds
# Size: 64000, Norm Time: 0.00571090 seconds

# %%
import platform

print("Python:", platform.python_version())
print("Machine:", platform.machine())
print("Processor:", platform.processor())
print("System:", platform.system())
# Out:
# Python: 3.13.15
# Machine: x86_64
# Processor: x86_64
# System: Linux
